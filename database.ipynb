# %%
import sqlite3


conn = sqlite3.connect('support.db')
cursor = conn.cursor()


cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
print("Tables:", cursor.fetchall())


print("\n--- Customers ---")
cursor.execute("SELECT * FROM customers")
for row in cursor.fetchall():
    print(row)


print("\n--- Tickets ---")
cursor.execute("SELECT * FROM tickets")
for row in cursor.fetchall():
    print(row)

conn.close()
# Out:
# Tables: [('customers',), ('sqlite_sequence',), ('tickets',)]
#
# --- Customers ---
# (1, 'John Doe', 'john.doe@example.com', '+1-555-0101', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (2, 'Jane Smith', 'jane.smith@example.com', '+1-555-0102', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (3, 'Bob Johnson', 'bob.johnson@example.com', '+1-555-0103', 'disabled', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (4, 'Alice Williams', 'alice.w@techcorp.com', '+1-555-0104', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (5, 'Charlie Brown', 'charlie.brown@email.com', '+1-555-0105', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (6, 'Diana Prince', 'diana.prince@company.org', '+1-555-0106', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (7, 'Edward Norton', 'e.norton@business.net', '+1-555-0107', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (8, 'Fiona Green', 'fiona.green@startup.io', '+1-555-0108', 'disabled', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (9, 'George Miller', 'george.m@enterprise.com', '+1-555-0109', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (10, 'Hannah Lee', 'hannah.lee@global.com', '+1-555-0110', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (11, 'Isaac Newton', 'isaac.n@science.edu', '+1-555-0111', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (12, 'Julia Roberts', 'julia.r@movies.com', '+1-555-0112', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (13, 'Kevin Chen', 'kevin.chen@tech.io', '+1-555-0113', 'disabled', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (14, 'Laura Martinez', 'laura.m@solutions.com', '+1-555-0114', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
# (15, 'Michael Scott', 'michael.scott@paper.com', '+1-555-0115', 'active', '2025-11-24 21:09:26', '2025-11-24 21:09:26')
#
# --- Tickets ---
# (1, 1, 'Cannot login to account', 'open', 'high', '2025-11-24 21:09:26')
# (2, 4, 'Database connection timeout errors', 'in_progress', 'high', '2025-11-24 21:09:26')
# (3, 7, 'Payment processing failing for all transactions', 'open', 'high', '2025-11-24 21:09:26')
# (4, 10, 'Critical security vulnerability found', 'in_progress', 'high', '2025-11-24 21:09:26')
# (5, 14, 'Website completely down', 'resolved', 'high', '2025-11-24 21:09:26')
# (6, 1, 'Password reset not working', 'in_progress', 'medium', '2025-11-24 21:09:26')
# (7, 2, 'Profile image upload fails', 'resolved', 'medium', '2025-11-24 21:09:26')
# (8, 5, 'Email notifications not being received', 'open', 'medium', '2025-11-24 21:09:26')
# (9, 6, 'Dashboard loading very slowly', 'in_progress', 'medium', '2025-11-24 21:09:26')
# (10, 9, 'Export to CSV feature broken', 'open', 'medium', '2025-11-24 21:09:26')
# (11, 11, 'Mobile app crashes on startup', 'resolved', 'medium', '2025-11-24 21:09:26')
# (12, 12, 'Search functionality returning wrong results', 'in_progress', 'medium', '2025-11-24 21:09:26')
# (13, 15, 'API rate limiting too restrictive', 'open', 'medium', '2025-11-24 21:09:26')
# (14, 2, 'Billing question about invoice', 'resolved', 'low', '2025-11-24 21:09:26')
# (15, 2, 'Feature request: dark mode', 'open', 'low', '2025-11-24 21:09:26')
# (16, 3, 'Documentation outdated for API v2', 'open', 'low', '2025-11-24 21:09:26')
# (17, 5, 'Typo in welcome email', 'resolved', 'low', '2025-11-24 21:09:26')
# (18, 6, 'Request for additional language support', 'open', 'low', '2025-11-24 21:09:26')
# (19, 9, 'Font size too small on settings page', 'resolved', 'low', '2025-11-24 21:09:26')
# (20, 11, 'Feature request: export to PDF', 'open', 'low', '2025-11-24 21:09:26')
# (21, 12, 'Color scheme suggestion for better contrast', 'open', 'low', '2025-11-24 21:09:26')
# (22, 14, 'Request access to beta features', 'in_progress', 'low', '2025-11-24 21:09:26')
# (23, 15, 'Question about pricing plans', 'resolved', 'low', '2025-11-24 21:09:26')
# (24, 4, 'Feature request: integration with Slack', 'open', 'low', '2025-11-24 21:09:26')
# (25, 10, 'Suggestion: add keyboard shortcuts', 'open', 'low', '2025-11-24 21:09:26')
# (26, 1, 'Urgent: System access problems', 'open', 'high', '2025-11-24 21:10:17')
# (27, 5, 'Critical billing error', 'open', 'high', '2025-11-24 21:10:17')
# (28, 7, 'Service outage impacting business', 'open', 'high', '2025-11-24 21:10:17')
# (29, 1, 'Urgent: System access problems', 'open', 'high', '2025-11-24 21:11:58')
# (30, 5, 'Critical billing error', 'open', 'high', '2025-11-24 21:11:58')
# (31, 7, 'Service outage impacting business', 'open', 'high', '2025-11-24 21:11:58')
